# %% [markdown]
# <a href="https://colab.research.google.com/github/s-kachroo/CMU-11785-TCR-CLEAN/blob/main/CMU_11785_CLEAN_Baseline_New_26K.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
run_name = '1028-v2'

# %%
# !git clone https://github.com/s-kachroo/CMU-11785-TCR-CLEAN.git
# Out:
# Cloning into 'CMU-11785-TCR-CLEAN'...
# remote: Enumerating objects: 24180, done.
# remote: Counting objects: 100% (326/326), done.
# remote: Compressing objects: 100% (192/192), done.
# remote: Total 24180 (delta 232), reused 151 (delta 134), pack-reused 23854 (from 1)
# Receiving objects: 100% (24180/24180), 173.31 MiB | 13.32 MiB/s, done.
# Resolving deltas: 100% (317/317), done.
# Updating files: 100% (23651/23651), done.

# %%
import os
os.chdir('/content/CMU-11785-TCR-CLEAN/app')
current_path = os.getcwd()
os.listdir(current_path)
# Out:
# ['train-supconH.py',
#  'build.py',
#  'src',
#  'train-triplet.py',
#  'results',
#  'data',
#  'gmm.py',
#  'inference.py',
#  'DEMO.ipynb',
#  'requirements.txt',
#  'CLEAN_infer_fasta.py']

# %%
# !pip install fair-esm
# Out:
# Collecting fair-esm
#   Downloading fair_esm-2.0.0-py3-none-any.whl.metadata (37 kB)
# Downloading fair_esm-2.0.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: fair-esm
# Successfully installed fair-esm-2.0.0

# %%
from src.CLEAN.utils import compute_esm_distance

embedding_folder_name = 'esm2_t33_650M_' + run_name

train_file_name = 'filtered_train_df_' + run_name
valid_file_name = 'filtered_valid_df_' + run_name
test_file_name = 'filtered_test_df_' + run_name
train_csv_name = train_file_name + '.csv'
valid_csv_name = valid_file_name + '.csv'
test_csv_name = test_file_name + '.csv'

train_csv_from = '/content/CMU-11785-TCR-CLEAN/app/data/' + run_name + '/filtered_train_df.csv'
train_csv_to = '/content/CMU-11785-TCR-CLEAN/app/data/' + train_csv_name
# !cp $train_csv_from $train_csv_to

valid_csv_from = '/content/CMU-11785-TCR-CLEAN/app/data/' + run_name + '/filtered_valid_df.csv'
valid_vsc_to = '/content/CMU-11785-TCR-CLEAN/app/data/' + valid_csv_name
# !cp $valid_csv_from $valid_vsc_to

test_csv_from = '/content/CMU-11785-TCR-CLEAN/app/data/' + run_name + '/filtered_test_df.csv'
test_csv_to = '/content/CMU-11785-TCR-CLEAN/app/data/' + test_csv_name
# !cp $test_csv_from $test_csv_to

compute_esm_distance(train_file_name, embedding_folder_name)
# Out:
# 100%|██████████| 192/192 [00:00<00:00, 2809.19it/s]
# Calculating distance map, number of unique EC is 192
# 192it [00:00, 1669.49it/s]

# %%
import pickle

pkl_train_file_name = '/content/CMU-11785-TCR-CLEAN/app/data/distance_map/' + train_file_name + '.pkl'
pkl_valid_file_name = '/content/CMU-11785-TCR-CLEAN/app/data/distance_map/' + valid_file_name + '.pkl'
pkl_test_file_name = '/content/CMU-11785-TCR-CLEAN/app/data/distance_map/' + test_file_name + '.pkl'

dist_map = pickle.load(open(pkl_train_file_name, 'rb'))
print(dist_map)
# Out:
# {'FLKEKGGL': {'FLKEKGGL': 0.0, 'ILKEPVHGV': 0.76961654, 'EIYKRWII': 0.36661354, 'QVPLRPMTYK': 0.3380317, 'KRWIILGLNK': 0.26384047, 'KAFSPEVIPMF': 0.56136715, 'NEGVKAAW': 0.32420626, 'LQPFPQPELPYPQPQ': 0.6184126, 'LLQTGIHVRVSQPSL': 0.3457062, 'EHPTFTSQYRIQGKL': 0.37978175, 'PKYVKQNTLKLAT': 0.34225, 'IVTDFSVIK': 0.2551365, 'ELAGIGILTV': 0.3171996, 'RAKFKQLL': 0.31200403, 'AVFDRKSDAK': 0.32092625, 'GILGFVFTL': 0.35420442, 'SLFNTVATLY': 0.52709246, 'RLRAEAQVK': 0.22028889, 'AYAQKIFKI': 0.25724432, 'LLDFVRFMGV': 0.43100703,
Y': 0.30701804, 'AYILFTRFFYV': 0.23333898, 'YIFFASFYY': 0.28479654, 'SSTFNVPMEKLK': 0.3716166, 'HTDFSSEIIGY': 0.4659827, 'FLPRVFSAV': 0.29783604, 'TFYLTNDVSFL': 0.33588988, 'FLLNKEMYL': 0.35433537, 'FLNGSCGSV': 0.2951383, 'VLAWLYAAV': 0.2857919, 'FLNRFTTTL': 0.3702313, 'MPASWVMRI': 0.3587335, 'NYSGVVTTVMF': 0.29014704, 'FRYMNSQGL': 0.47029924, 'KLWAQCVQL': 0.2789676, 'FTYASALWEI': 0.3203981, 'SEISMDNSPNL': 0.27981105, 'LLMPILTLT': 0.26061964, 'ILHCANFNV': 0.39131957, 'FPPTSFGPL': 0.25481233, 'FVDGVPFVV': 0.25053233, 'ISDYDYYRY': 0.28189468, 'RQLLFVVEV': 0.3166841, 'RLYYDSMSY': 0.4819211, 'ATVVIGTSK': 0.40978277, 'LSDDAVVCFNSTY': 0.4219434, 'RILGAGCFV': 0.5236848, 'VLQAVGACV': 0.5548787, 'LVLSVNPYV': 0.39696324, 'KLSYGIATV': 0.2135751, 'VVYRGTTTY': 0.31228292, 'KLNVGDYFV': 0.19599165, 'TLVPQEHYV': 0.28708696, 'SSNVANYQK': 0.42480576, 'YVFCTVNAL': 0.36424145, 'IVDTVSALV': 0.28697753, 'ILGLPTQTV': 0.31323284, 'IPRRNVATL': 0.38388714, 'VLWAHGFEL': 0.40380588, 'AIMTRCLAV': 0.37462234, 'ALLADKFPV': 0.4088137, 'YLDAYNMMI': 0.24275145, 'MMISAGFSL': 0.44463757, 'NLWNTFTRL': 0.40700936, 'TTLPVNVAF': 0.3765916, 'GVAMPNLYK': 0.32616606, 'KMQRMLLEK': 0.36255494, 'YLNTLTLAV': 0.2971393, 'TLIGDCATV': 0.28647628, 'LPPAYTNSF': 0.3684661, 'TEKSNIIRGW': 0.4807444, 'TLDSKTQSL': 0.6515941, 'IYSKHTPINL': 0.39620838, 'TPINLVRDL': 0.3075792, 'LEPLVDLPI': 0.1713009, 'LLALHRSYL': 0.5273017, 'RISNCVADY': 0.5293783, 'KLPDDFTGCV': 0.27513057, 'NLDSKVGGNY': 0.71084446, 'RLFRKSNLK': 0.3543263, 'YFPLQSYGF': 0.2816143, 'FQPTNGVGY': 0.36950597, 'EILDITPCSF': 0.29663575,  ...

# %%
# !git pull origin main
# Out:
# From https://github.com/s-kachroo/CMU-11785-TCR-CLEAN
#  * branch              main       -> FETCH_HEAD
# Already up to date.

# %%
# For new FOR loop in Dataloader.py
# !python train-triplet.py --training_data {train_file_name} --model_name {embedding_folder_name} --dir_name {embedding_folder_name} --epoch 26000 --batch_size 6000 --learning_rate 3e-4 --adaptive_rate 100000000 --new_full_list

# For old FOR loop in Dataloader.py
# !python train-triplet.py --training_data {train_file_name} --model_name {embedding_folder_name} --dir_name {embedding_folder_name} --epoch 10 --batch_size 6000 --learning_rate 3e-4 --adaptive_rate 100000000 --old_full_list
# Out:
# Streaming output truncated to the last 5000 lines.
# ---------------------------------------------------------------------------
# | end of epoch 24335 | time:  0.18s | training loss 0.5280
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25956 | time:  0.17s | training loss 0.6532
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25957 | time:  0.17s | training loss 0.5597
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25958 | time:  0.17s | training loss 0.5476
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25959 | time:  0.17s | training loss 0.5756
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25960 | time:  0.17s | training loss 0.4991
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25961 | time:  0.17s | training loss 0.6382
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25962 | time:  0.17s | training loss 0.6006
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25963 | time:  0.17s | training loss 0.5500
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25964 | time:  0.17s | training loss 0.5544
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25965 | time:  0.17s | training loss 0.5763
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25966 | time:  0.17s | training loss 0.5978
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25967 | time:  0.17s | training loss 0.6810
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25968 | time:  0.17s | training loss 0.5447
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25969 | time:  0.18s | training loss 0.6075
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25970 | time:  0.17s | training loss 0.5765
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25971 | time:  0.17s | training loss 0.6023
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25972 | time:  0.17s | training loss 0.6795
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25973 | time:  0.17s | training loss 0.5967
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25974 | time:  0.17s | training loss 0.5557
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25975 | time:  0.17s | training loss 0.6069
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25976 | time:  0.17s | training loss 0.5983
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25977 | time:  0.17s | training loss 0.6128
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25978 | time:  0.17s | training loss 0.5833
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25979 | time:  0.17s | training loss 0.6119
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25980 | time:  0.17s | training loss 0.5855
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25981 | time:  0.17s | training loss 0.6109
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25982 | time:  0.17s | training loss 0.6191
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25983 | time:  0.17s | training loss 0.5778
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25984 | time:  0.17s | training loss 0.5748
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25985 | time:  0.17s | training loss 0.5944
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25986 | time:  0.17s | training loss 0.6171
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25987 | time:  0.17s | training loss 0.6680
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25988 | time:  0.17s | training loss 0.5884
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25989 | time:  0.17s | training loss 0.5531
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25990 | time:  0.17s | training loss 0.5843
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25991 | time:  0.19s | training loss 0.5462
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25992 | time:  0.18s | training loss 0.5846
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25993 | time:  0.17s | training loss 0.6065
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25994 | time:  0.17s | training loss 0.5983
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25995 | time:  0.17s | training loss 0.6393
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25996 | time:  0.17s | training loss 0.6117
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25997 | time:  0.17s | training loss 0.5855
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25998 | time:  0.19s | training loss 0.5055
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25999 | time:  0.17s | training loss 0.5609
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 26000 | time:  0.18s | training loss 0.5238
# ---------------------------------------------------------------------------

# %%
# !git pull origin main
# Out:
# From https://github.com/s-kachroo/CMU-11785-TCR-CLEAN
#  * branch              main       -> FETCH_HEAD
# Already up to date.

# %%
from src.CLEAN.infer import infer_maxsep
infer_maxsep(train_data=train_file_name, test_data=test_file_name, report_metrics=True, pretrained=False, model_name=embedding_folder_name, dir_name=embedding_folder_name)

# Cleanup files
os.remove(train_csv_to)
os.remove(valid_vsc_to)
os.remove(test_csv_to)
# Out:
# The embedding sizes for train and test: torch.Size([16532, 128]) torch.Size([4680, 128])
# 100%|██████████| 192/192 [00:00<00:00, 17545.95it/s]
# Calculating eval distance map, between 4680 test ids and 192 train EC cluster centers
# 4680it [00:00, 6608.37it/s]
# ############ EC calling results using maximum separation ############
# ---------------------------------------------------------------------------
# >>> total samples: 4680 | total ec: 191
# >>> precision: 0.0551 | recall: 0.0462| F1: 0.0371 | AUC: 0.52
# ---------------------------------------------------------------------------
