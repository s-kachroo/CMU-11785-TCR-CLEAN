# %% [markdown]
# <a href="https://colab.research.google.com/github/s-kachroo/CMU-11785-TCR-CLEAN/blob/main/CMU_11785_CLEAN_Baseline_Old_26K.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
run_name = '1028-v2'

# %%
# !git clone https://github.com/s-kachroo/CMU-11785-TCR-CLEAN.git
# Out:
# Cloning into 'CMU-11785-TCR-CLEAN'...
# remote: Enumerating objects: 24192, done.
# remote: Counting objects: 100% (338/338), done.
# remote: Compressing objects: 100% (204/204), done.
# remote: Total 24192 (delta 239), reused 151 (delta 134), pack-reused 23854 (from 1)
# Receiving objects: 100% (24192/24192), 173.64 MiB | 10.60 MiB/s, done.
# Resolving deltas: 100% (324/324), done.
# Updating files: 100% (23653/23653), done.

# %%
import os
os.chdir('/content/CMU-11785-TCR-CLEAN/app')
current_path = os.getcwd()
os.listdir(current_path)
# Out:
# ['train-supconH.py',
#  'build.py',
#  'src',
#  'train-triplet.py',
#  'results',
#  'data',
#  'gmm.py',
#  'inference.py',
#  'DEMO.ipynb',
#  'requirements.txt',
#  'CLEAN_infer_fasta.py']

# %%
# !pip install fair-esm
# Out:
# Collecting fair-esm
#   Downloading fair_esm-2.0.0-py3-none-any.whl.metadata (37 kB)
# Downloading fair_esm-2.0.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: fair-esm
# Successfully installed fair-esm-2.0.0

# %%
from src.CLEAN.utils import compute_esm_distance

embedding_folder_name = 'esm2_t33_650M_' + run_name

train_file_name = 'filtered_train_df_' + run_name
valid_file_name = 'filtered_valid_df_' + run_name
test_file_name = 'filtered_test_df_' + run_name
train_csv_name = train_file_name + '.csv'
valid_csv_name = valid_file_name + '.csv'
test_csv_name = test_file_name + '.csv'

train_csv_from = '/content/CMU-11785-TCR-CLEAN/app/data/' + run_name + '/filtered_train_df.csv'
train_csv_to = '/content/CMU-11785-TCR-CLEAN/app/data/' + train_csv_name
# !cp $train_csv_from $train_csv_to

valid_csv_from = '/content/CMU-11785-TCR-CLEAN/app/data/' + run_name + '/filtered_valid_df.csv'
valid_vsc_to = '/content/CMU-11785-TCR-CLEAN/app/data/' + valid_csv_name
# !cp $valid_csv_from $valid_vsc_to

test_csv_from = '/content/CMU-11785-TCR-CLEAN/app/data/' + run_name + '/filtered_test_df.csv'
test_csv_to = '/content/CMU-11785-TCR-CLEAN/app/data/' + test_csv_name
# !cp $test_csv_from $test_csv_to

compute_esm_distance(train_file_name, embedding_folder_name)
# Out:
# 100%|██████████| 192/192 [00:00<00:00, 2524.64it/s]
# Calculating distance map, number of unique EC is 192
# 192it [00:00, 1569.36it/s]

# %%
import pickle

pkl_train_file_name = '/content/CMU-11785-TCR-CLEAN/app/data/distance_map/' + train_file_name + '.pkl'
pkl_valid_file_name = '/content/CMU-11785-TCR-CLEAN/app/data/distance_map/' + valid_file_name + '.pkl'
pkl_test_file_name = '/content/CMU-11785-TCR-CLEAN/app/data/distance_map/' + test_file_name + '.pkl'

dist_map = pickle.load(open(pkl_train_file_name, 'rb'))
print(dist_map)
# Out:
# {'FLKEKGGL': {'FLKEKGGL': 0.0, 'ILKEPVHGV': 0.7696163, 'EIYKRWII': 0.36661354, 'QVPLRPMTYK': 0.3380317, 'KRWIILGLNK': 0.26384047, 'KAFSPEVIPMF': 0.56136715, 'NEGVKAAW': 0.3242064, 'LQPFPQPELPYPQPQ': 0.6184126, 'LLQTGIHVRVSQPSL': 0.3457063, 'EHPTFTSQYRIQGKL': 0.37978178, 'PKYVKQNTLKLAT': 0.34225014, 'IVTDFSVIK': 0.25513643, 'ELAGIGILTV': 0.31719956, 'RAKFKQLL': 0.31200406, 'AVFDRKSDAK': 0.32092628, 'GILGFVFTL': 0.35420445, '
TTDPSFLGRY': 0.28781322, 'FADDLNQLTGY': 0.38640243, 'ITEEVGHTDLMAAY': 0.30701804, 'AYILFTRFFYV': 0.233339, 'YIFFASFYY': 0.28479648, 'SSTFNVPMEKLK': 0.3716166, 'HTDFSSEIIGY': 0.4659827, 'FLPRVFSAV': 0.29783598, 'TFYLTNDVSFL': 0.33588988, 'FLLNKEMYL': 0.3543354, 'FLNGSCGSV': 0.29513833, 'VLAWLYAAV': 0.28579193, 'FLNRFTTTL': 0.3702313, 'MPASWVMRI': 0.3587335, 'NYSGVVTTVMF': 0.29014707, 'FRYMNSQGL': 0.4702993, 'KLWAQCVQL': 0.27896768, 'FTYASALWEI': 0.3203981, 'SEISMDNSPNL': 0.2798111, 'LLMPILTLT': 0.26061967, 'ILHCANFNV': 0.39131957, 'FPPTSFGPL': 0.2548123, 'FVDGVPFVV': 0.25053233, 'ISDYDYYRY': 0.28189465, 'RQLLFVVEV': 0.3166841, 'RLYYDSMSY': 0.48192105, 'ATVVIGTSK': 0.40978277, 'LSDDAVVCFNSTY': 0.42194337, 'RILGAGCFV': 0.5236848, 'VLQAVGACV': 0.5548787, 'LVLSVNPYV': 0.3969633, 'KLSYGIATV': 0.21357511, 'VVYRGTTTY': 0.3122829, 'KLNVGDYFV': 0.19599159, 'TLVPQEHYV': 0.28708693, 'SSNVANYQK': 0.4248058, 'YVFCTVNAL': 0.36424157, 'IVDTVSALV': 0.28697753, 'ILGLPTQTV': 0.31323284, 'IPRRNVATL': 0.3838871, 'VLWAHGFEL': 0.4038059, 'AIMTRCLAV': 0.37462232, 'ALLADKFPV': 0.4088137, 'YLDAYNMMI': 0.24275143, 'MMISAGFSL': 0.4446376, 'NLWNTFTRL': 0.40700954, 'TTLPVNVAF': 0.3765916, 'GVAMPNLYK': 0.32616606, 'KMQRMLLEK': 0.3625549, 'YLNTLTLAV': 0.2971393, 'TLIGDCATV': 0.2864763, 'LPPAYTNSF': 0.36846614, 'TEKSNIIRGW': 0.4807444, 'TLDSKTQSL': 0.65159416, 'IYSKHTPINL': 0.39620835, 'TPINLVRDL': 0.30757922, 'LEPLVDLPI': 0.17130074, 'LLALHRSYL': 0.5273017, 'RISNCVADY': 0.52937806, 'KLPDDFTGCV': 0.2751307, 'NLDSKVGGNY': 0.71084446, 'RLFRKSNLK': 0.35432637, 'YFPLQSYGF': 0.2816143, 'FQPTNGVGY': 0.36950594, 'EILDITPCSF': 0.29663566 ...

# %%
# !git pull origin main
# Out:
# From https://github.com/s-kachroo/CMU-11785-TCR-CLEAN
#  * branch              main       -> FETCH_HEAD
# Already up to date.

# %%
# For new FOR loop in Dataloader.py
# !python train-triplet.py --training_data {train_file_name} --model_name {embedding_folder_name} --dir_name {embedding_folder_name} --epoch 26000 --batch_size 6000 --learning_rate 3e-4 --adaptive_rate 100000000 --new_full_list

# For old FOR loop in Dataloader.py
# !python train-triplet.py --training_data {train_file_name} --model_name {embedding_folder_name} --dir_name {embedding_folder_name} --epoch 26000 --batch_size 6000 --learning_rate 3e-4 --adaptive_rate 100000000 --old_full_list
# Out:
# Streaming output truncated to the last 5000 lines.
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25963 | time:  0.13s | training loss 0.5075
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25964 | time:  0.14s | training loss 0.6103
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25965 | time:  0.13s | training loss 0.5382
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25966 | time:  0.13s | training loss 0.5917
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25967 | time:  0.14s | training loss 0.6066
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25968 | time:  0.14s | training loss 0.5560
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25969 | time:  0.14s | training loss 0.5234
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25970 | time:  0.13s | training loss 0.6323
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25971 | time:  0.13s | training loss 0.6042
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25972 | time:  0.13s | training loss 0.5615
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25973 | time:  0.13s | training loss 0.6662
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25974 | time:  0.13s | training loss 0.5444
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25975 | time:  0.13s | training loss 0.6841
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25976 | time:  0.13s | training loss 0.5958
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25977 | time:  0.13s | training loss 0.5208
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25978 | time:  0.13s | training loss 0.6338
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25979 | time:  0.13s | training loss 0.6127
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25980 | time:  0.13s | training loss 0.6002
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25981 | time:  0.13s | training loss 0.5202
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25982 | time:  0.13s | training loss 0.6613
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25983 | time:  0.13s | training loss 0.5201
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25984 | time:  0.13s | training loss 0.5909
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25985 | time:  0.13s | training loss 0.5641
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25986 | time:  0.13s | training loss 0.6034
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25987 | time:  0.13s | training loss 0.5985
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25988 | time:  0.13s | training loss 0.5666
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25989 | time:  0.13s | training loss 0.6353
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25990 | time:  0.14s | training loss 0.5563
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25991 | time:  0.13s | training loss 0.5245
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25992 | time:  0.13s | training loss 0.6340
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25993 | time:  0.13s | training loss 0.5880
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25994 | time:  0.13s | training loss 0.5730
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25995 | time:  0.13s | training loss 0.5383
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25996 | time:  0.13s | training loss 0.5424
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25997 | time:  0.13s | training loss 0.5257
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25998 | time:  0.14s | training loss 0.5810
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 25999 | time:  0.13s | training loss 0.5555
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 26000 | time:  0.13s | training loss 0.6352
# ---------------------------------------------------------------------------

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 2 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (2/2), 894 bytes | 894.00 KiB/s, done.
# From https://github.com/s-kachroo/CMU-11785-TCR-CLEAN
#  * branch              main       -> FETCH_HEAD
#    6508de0a..733b93b5  main       -> origin/main
# Updating 6508de0a..733b93b5
# Fast-forward
#  CMU_11785_CLEAN_RESULTS.ipynb | 10496 ------------------------------------------------------------
#  1 file changed, 10496 deletions(-)
#  delete mode 100644 CMU_11785_CLEAN_RESULTS.ipynb

# %%
from src.CLEAN.infer import infer_maxsep
infer_maxsep(train_data=train_file_name, test_data=test_file_name, report_metrics=True, pretrained=False, model_name=embedding_folder_name, dir_name=embedding_folder_name)

# Cleanup files
os.remove(train_csv_to)
os.remove(valid_vsc_to)
os.remove(test_csv_to)
# Out:
# The embedding sizes for train and test: torch.Size([16532, 128]) torch.Size([4680, 128])
# 100%|██████████| 192/192 [00:00<00:00, 17595.79it/s]
# Calculating eval distance map, between 4680 test ids and 192 train EC cluster centers
# 4680it [00:00, 6407.61it/s]
# ############ EC calling results using maximum separation ############
# ---------------------------------------------------------------------------
# >>> total samples: 4680 | total ec: 191
# >>> precision: 0.0408 | recall: 0.0316| F1: 0.0219 | AUC: 0.514
# ---------------------------------------------------------------------------
